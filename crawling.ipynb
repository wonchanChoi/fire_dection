# %%
from selenium import webdriver
from bs4 import BeautifulSoup

import urllib
import os

# %%
driver = webdriver.Firefox(executable_path = './geckodriver')
driver.get('https://www.google.co.kr/imghp')

# %%
#keyword = input()
keyword="산"
driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/form/div[2]/div[1]/div[1]/div/div[2]/input').send_keys(keyword)
driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/form/div[2]/div[1]/div[1]/div/div[2]/input').send_keys(webdriver.common.keys.Keys.ENTER)

# %%
for i in range(100):
    driver.execute_script("window.scrollBy(0,10000)")

#c=driver.find_element_by_xpath('/html/body/div[2]/c-wiz/div[3]/div[1]/div/div/div/div/div[5]/input')
#c.click()

#for i in range(1000):
    #driver.execute_script("window.scrollBy(0,10000)")

# %%
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')
img = soup.findAll("img")

fileNum=0
srcURL=[]
for line in img:
   if str(line).find('data-src') != -1:  
      print(fileNum, " : ", line['data-src'])  
      srcURL.append(line['data-src'])
      fileNum+=1
# Out:
# 0  :  https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSkDpNDntGufjSsFtX-XPSltBTueqDsQAKzHQ&usqp=CAU
# 1  :  https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS0ePP-lIkQDekrI2tVG9_tGAn7K6jwfT8R4Q&usqp=CAU
# 2  :  https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSNZxbJQjOgIeGmQHPlHPwBaSIN4LipYyruug&usqp=CAU
# 3  :  https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRImKZUsB8j7rB64350fME0DZg0PNTfOe5o7w&usqp=CAU
# 4  :  https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSL35wM-SznzLB2MSGE_JuhIe-z2Ul0av_Gvw&usqp=CAU
# 5  :  https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcR8zlF5mcPFzlDyC2IuofVKXVfTYD7Mw22oQA&usqp=CAU
# 6  :  https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSdgNC74MQoo7BS78CwlKotBALONRvJaWy8mg&usqp=CAU
# 7  :  https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTBm5OotQXApPcwIS3LtuV5zk2s2UZ2-huyZw&usqp=CAU
# 8  :  https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSvhx2APmU_kjwe0-UmLjMZ3z6gHLO_jeLTWw&usqp=CAU
# ...

# %%
path='./img/train/normal'

try:
    if not(os.path.isdir(path)):
        os.makedirs(os.path.join(path))
except OSError as e:
    if e.errno != errno.EEXIST:
        print("Failed to create directory!!!!!")
        raise

for i,src in zip(range(fileNum),srcURL):
    urllib.request.urlretrieve(src, path+"/m"+str(i)+".jpg")
    print(i,"saved")
print("complete")
# Out:
# 0 saved
# 1 saved
# 2 saved
# 3 saved
# 4 saved
# 5 saved
# 6 saved
# 7 saved
# 8 saved
# 9 saved
# 10 saved
# 11 saved
# 12 saved
# 13 saved
# 14 saved
# 15 saved
# 16 saved
# 17 saved
# 18 saved
# 19 saved
# 20 saved
# 21 saved
# 22 saved
# 23 saved
# 24 saved
# 25 saved
# 26 saved
# 27 saved
# 28 saved
# 29 saved
# 30 saved
# 31 saved
# 32 saved
# 33 saved
# 34 saved
# 35 saved
# 36 saved
# 37 saved
# 38 saved
# 39 saved
# 40 saved
# 41 saved
# 42 saved
# 43 saved
# 44 saved
# 45 saved
# 46 saved
# 47 saved
# 48 saved
# 49 saved
# 50 saved
# 51 saved
# 52 saved
# 53 saved
# 54 saved
# 55 saved
# 56 saved
# 57 saved
# 58 saved
# 59 saved
# 60 saved
# 61 saved
# 62 saved
# 63 saved
# 64 saved
# 65 saved
# 66 saved
# 67 saved
# 68 saved
# 69 saved
# 70 saved
# 71 saved
# 72 saved
# 73 saved
# 74 saved
# 75 saved
# 76 saved
# 77 saved
# 78 saved
# 79 saved
# 80 saved
# 81 saved
# 82 saved
# 83 saved
# 84 saved
# 85 saved
# 86 saved
# 87 saved
# 88 saved
# 89 saved
# 90 saved
# ...

# %%
driver.close()
